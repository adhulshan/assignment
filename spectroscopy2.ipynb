# %%
import pandas as pd
import  glob as gb
import matplotlib.pyplot as plt

# %%
path='C:/Users/adhul/Desktop/spectroscopy'

# %%
files = gb.glob(path + "/*.csv")

# %%
lis=[]
for f in files:
    tdf = pd.read_csv(f)
    lis.append(tdf.loc[tdf['0']==179.714460,'0.1'].squeeze())
df=pd.Series(lis)

# %%
plt.xlabel("DataFrame")
plt.ylabel("Intensity")
df.plot(figsize=(10,7))
plt.show()
